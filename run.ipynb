# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !./create_corpus_index.py
# Out:
# Read 396 words from words.txt.
# Saved index of 10000 pages to corpus/Africa.index.
# Saved index of 8939 pages to corpus/Agent.index.
# Saved index of 10000 pages to corpus/Air.index.
# Saved index of 8751 pages to corpus/Alien.index.
# Saved index of 10000 pages to corpus/Alps.index.
# Saved index of 8958 pages to corpus/Amazon.index.
# Saved index of 9619 pages to corpus/Ambulance.index.
# Saved index of 10000 pages to corpus/America.index.
# Saved index of 10000 pages to corpus/Angel.index.
# Saved index of 10000 pages to corpus/Antarctica.index.
# Saved index of 9885 pages to corpus/Apple.index.
# Saved index of 10000 pages to corpus/Arm.index.
# Saved index of 10000 pages to corpus/Atlantis.index.
# Saved index of 10000 pages to corpus/Australia.index.
# Saved index of 9658 pages to corpus/Aztec.index.
# Saved index of 8869 pages to corpus/Back.index.
# Saved index of 9712 pages to corpus/Ball.index.
# Saved index of 9284 pages to corpus/Band.index.
# ...

# %%
# !./fetch_corpus_text.py
# Out:
# Read 396 words from words.txt.
# Good file "corpus/Princess.txt.gz" below minimum size: 3723773 < 5000000.0.
# Good file "corpus/Server.txt.gz" below minimum size: 2493234 < 5000000.0.
# Good file "corpus/Park.txt.gz" below minimum size: 4112687 < 5000000.0.
# Fetching from 8461 pages for Server.
# Fetching from 10000 pages for Princess.
# Fetching from 10000 pages for Park.
# Good file "corpus/Shoe.txt.gz" below minimum size: 2486278 < 5000000.0.
# Fetching from 10000 pages for Shoe.
# Good file "corpus/Skyscraper.txt.gz" below minimum size: 4609380 < 5000000.0.
# Good file "corpus/Pool.txt.gz" below minimum size: 2507685 < 5000000.0.
# Good file "corpus/Row.txt.gz" below minimum size: 4999945 < 5000000.0.
# Fetching from 10000 pages for Skyscraper.
# Fetching from 9024 pages for Row.
# Fetching from 9591 pages for Pool.
# Good file "corpus/Spell.txt.gz" below minimum size: 603873 < 5000000.0.
# Fetching from 9236 pages for Spell.
# ...

# %%
# !./preprocess_corpus.py
# Out:
# Wordlist contains 0 compound words:
# dict_keys([])
# Africa 31652 770068
# Agent 34522 780338
# Air 31727 768653
# Alien 32457 802271
# Alps 33753 783776
# Amazon 34526 794480
# Ambulance 35743 780342
# America 30908 766067
# Angel 34942 815802
# Antarctica 34486 798801
# Apple 32704 785002
# Arm 34136 784885
# Atlantis 32497 799362
# Australia 31067 781428
# Aztec 32365 790307
# Back 34497 803825
# Ball 34792 824665
# Band 32135 804450
# Bank 31872 792965
# Bar 30540 720504
# Bark 38071 778514
# Bat 34184 778272
# Battery 34916 785442
# Beach 33748 791272
# Bear 34341 795193
# Beat 34415 810734
# Bed 33584 774675
# Beijing 31204 776895
# Bell 33652 784558
# Belt 32372 778738
# Berlin 32533 781887
# Bermuda 31095 778632
# Berry 34813 785503
# Bill 33049 797697
# Block 32249 751874
# Board 31045 776611
# Bolt 33843 801870
# Bomb 33801 795297
# Bond 32140 743461
# Boom 34160 793606
# Boot 33339 795958
# Bottle 34312 792673
# Bow 37109 807900
# Box 33614 797822
# Bridge 33856 781317
# ...

# %%
# !./learn.py --workers 20 --npass 1
# !./evaluate.py --npass 1 --top-singles 50 --top-pairs 0 --save-plots /home/jovyan/work/images/dat_1

# %%
# !./learn.py --workers 20 --npass 2
# !./evaluate.py --npass 2 --top-singles 50 --top-pairs 0 --save-plots /home/jovyan/work/images/dat_2
# Out:
# 2020-05-09 09:32:31,064 : INFO : Using corpus corpus_2.gz
# 2020-05-09 09:32:31,689 : INFO : Learning rate: 0.0201 -> 0.0151
# 2020-05-09 09:32:31,689 : INFO : loading Word2Vec object from embeddings/custom/word2vec.dat.1
# 2020-05-09 09:32:32,189 : INFO : loading wv recursively from embeddings/custom/word2vec.dat.1.wv.* with mmap=None
# 2020-05-09 09:32:32,190 : INFO : loading vectors from embeddings/custom/word2vec.dat.1.wv.vectors.npy with mmap=None
# 2020-05-09 09:32:32,222 : INFO : setting ignored attribute vectors_norm to None
# 2020-05-09 09:32:32,223 : INFO : loading vocabulary recursively from embeddings/custom/word2vec.dat.1.vocabulary.* with mmap=None
# 2020-05-09 09:32:32,223 : INFO : loading trainables recursively from embeddings/custom/word2vec.dat.1.trainables.* with mmap=None
# 2020-05-09 09:32:32,223 : INFO : loading syn1 from embeddings/custom/word2vec.dat.1.trainables.syn1.npy with mmap=None
# ...

# %%
# !./learn.py --workers 20 --npass 3
# !./evaluate.py --npass 3 --top-singles 50 --top-pairs 0 --save-plots /home/jovyan/work/images/dat_3

# %%
# !./learn.py --workers 20 --npass 4
# !./evaluate.py --npass 4 --top-singles 50 --top-pairs 0 --save-plots /home/jovyan/work/images/dat_4

# %%
# !./learn.py --workers 20 --npass 5
# !./evaluate.py --npass 5 --top-singles 10 --top-pairs 10 --save-plots /home/jovyan/work/images/dat_5
