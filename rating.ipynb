# %%
from gensim.test.utils import get_tmpfile
from gensim.models import KeyedVectors

# %%
word2vec_file = get_tmpfile('/home/jovyan/work/embeddings/word2vec/glove.6B.300d.txt')
word2vec = KeyedVectors.load_word2vec_format(word2vec_file)
model = model.WordEmbedding(word2vec)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-782fce4ebf9d> in <module>
#       1 word2vec_file = get_tmpfile('/home/jovyan/work/embeddings/word2vec/glove.6B.300d.txt')
# ----> 2 word2vec = KeyedVectors.load_word2vec_format(word2vec_file)
#       3 model = model.WordEmbedding(word2vec)
#
# /opt/venv/lib/python3.7/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1547         return _load_word2vec_format(
#    1548             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1549             limit=limit, datatype=datatype)
#    1550
#    1551     @classmethod
#
# /opt/venv/lib/python3.7/site-packages/gensim/models/utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, binary_chunk_size)
#     286                 vocab_size, vector_size, datatype, unicode_errors, binary_chunk_size)
#     287         else:
# --> 288             _word2vec_read_text(fin, result, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#     289     if result.vectors.shape[0] != len(result.vocab):
#     290         logger.info(
#
# /opt/venv/lib/python3.7/site-packages/gensim/models/utils_any2vec.py in _word2vec_read_text(fin, result, counts, vocab_size, vector_size, datatype, unicode_errors, encoding)
#     219         if len(parts) != vector_size + 1:
#     220             raise ValueError("invalid vector on line %s (is this really the text format?)" % line_no)
# --> 221         word, weights = parts[0], [datatype(x) for x in parts[1:]]
#     222         _add_word_to_result(result, counts, word, weights, vocab_size)
#     223
#
# /opt/venv/lib/python3.7/site-packages/gensim/models/utils_any2vec.py in <listcomp>(.0)
#     219         if len(parts) != vector_size + 1:
#     220             raise ValueError("invalid vector on line %s (is this really the text format?)" % line_no)
# --> 221         word, weights = parts[0], [datatype(x) for x in parts[1:]]
#     222         _add_word_to_result(result, counts, word, weights, vocab_size)
#     223
#
# KeyboardInterrupt:

# %%
model.get_closest(['night'], ['bat', 'night'], ['bed'], ['mass'])
