# %%
# !python --version
# Out:
# Python 3.7.3

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2020-05-08 14:03:54--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# connected. to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80...
# 302 Foundest sent, awaiting response...
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2020-05-08 14:03:54--  https://nlp.stanford.edu/data/glove.6B.zip
# connected. to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443...
# 301 Moved Permanentlyaiting response...
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2020-05-08 14:03:55--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# 171.64.64.22wnloads.cs.stanford.edu (downloads.cs.stanford.edu)...
# connected. to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80...
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip.1’
#
# ^Cove.6B.zip.1        8%[>                   ]  66.05M  7.18MB/s    eta 96s

# %%
import zipfile
zip_ref = zipfile.ZipFile('glove.6B.zip', 'r')
zip_ref.extractall('glove embeddings')
zip_ref.close()

# %%
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
embeddings_dict = {}
with open("glove embeddings/glove.6B.50d.txt", 'r') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
def find_closest_embeddings(embedding):
    return sorted(embeddings_dict.keys(), key=lambda word: spatial.distance.euclidean(embeddings_dict[word], embedding))

# %%
# !./play.py --config CHCH --seed 345
